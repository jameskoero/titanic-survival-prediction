# %% [markdown]
# # Titanic EDA\n\nThis notebook provides exploratory analysis of the Titanic training dataset in `data/raw/train.csv`.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('../data/raw/train.csv')\ndf.head()

# %%
df.isnull().sum()

# %%
df['Survived'].value_counts(normalize=True).plot(kind='bar', title='Survival Distribution')\nplt.show()
