# %% [markdown]
# # Titanic Modelling\n\nThis notebook runs the modular preprocessing, training, and evaluation workflow from `src/`.

# %%
import subprocess\nsubprocess.run(["python", "../src/preprocess.py", "--input", "../data/raw/train.csv", "--output", "../data/processed/train_processed.csv"], check=True)

# %%
import subprocess\nsubprocess.run(["python", "../src/train.py", "--input", "../data/processed/train_processed.csv"], check=True)

# %%
import subprocess\nsubprocess.run(["python", "../src/evaluate.py", "--input", "../data/processed/train_processed.csv"], check=True)
